# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
df = pd.read_csv(r"C:\Users\91914\Desktop\Insertion thread detection Mini project\thread_dataset.csv")

# %%
df
# Out:
#    Unique id                                       subject  Unnamed: 2  \
# 0          1                                Access control         NaN
# 1          2                          Requirements for job         NaN
# 2          3                       Interest in opportunity         NaN
# 3          4                              Official records         NaN
# 4          5                                 Project files         NaN
# 5          6                              Leave permission         NaN
# 6          7                          Requirements for job         NaN
# 7          8                  Independence day celebration         NaN
# 8          9                                     Data leak         NaN
# 9         10                                   Reply email         NaN
# 10        11                                        Picnic         NaN
# 11        12                                  Data sharing         NaN
# ...

# %%
df['text'] = df['text'].str.lower()
# For simplicity, let's just convert text to lowercase here

# %%
df
# Out:
#    Unique id                                       subject  Unnamed: 2  \
# 0          1                                Access control         NaN
# 1          2                          Requirements for job         NaN
# 2          3                       Interest in opportunity         NaN
# 3          4                              Official records         NaN
# 4          5                                 Project files         NaN
# 5          6                              Leave permission         NaN
# 6          7                          Requirements for job         NaN
# 7          8                  Independence day celebration         NaN
# 8          9                                     Data leak         NaN
# 9         10                                   Reply email         NaN
# 10        11                                        Picnic         NaN
# 11        12                                  Data sharing         NaN
# ...

# %%
# Splitting data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(df['text'], df['thread'], test_size=0.2, random_state=42)

# %%
# Feature extraction using TF-IDF
tfidf_vectorizer = TfidfVectorizer()
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
X_test_tfidf = tfidf_vectorizer.transform(X_test)

# %%
# Training SVM model
svm_model = SVC(kernel='linear')
svm_model.fit(X_train_tfidf, y_train)
# Out:
# SVC(kernel='linear')

# %%
# Predictions
y_pred = svm_model.predict(X_test_tfidf)

# %%
# Evaluation
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.9090909090909091
# Precision: 0.75
# Recall: 1.0
# F1 Score: 0.8571428571428571
